# %% [markdown]
# # Github

# %%
print("Hola GitHub")
print("Prueba 01: subir notebook desde VS Code")
# Out:
# Hola GitHub
# Prueba 01: subir notebook desde VS Code

# %%
print("Segundo commit: cambio desde VS Code")
# Out:
# Segundo commit: cambio desde VS Code
